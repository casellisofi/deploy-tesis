# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
df = pd.read_csv('C:/Users/Sofia/Documents/despegar/reclamos-lh/datasets/arg/ARGENTINA.csv',sep=';',encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6456/3989690189.py in <module>
#       1 import pandas as pd
# ----> 2 import plotly.express as px
#       3 import matplotlib.pyplot as plt
#       4 df = pd.read_csv('C:/Users/Sofia/Documents/despegar/reclamos-lh/datasets/arg/ARGENTINA.csv',sep=';',encoding='latin-1')
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import nltk 
#Tokenización de reclamos
def tokenize(df):
    df2 = nltk.tokenize.word_tokenize(df)
    return df2

# %%
import plotly.figure_factory as ff

z = [[0.1, 0.3, 0.5, 0.2],
     [1.0, 0.8, 0.6, 0.1],
     [0.1, 0.3, 0.6, 0.9],
     [0.6, 0.4, 0.2, 0.2]]

x = ['healthy', 'multiple diseases', 'Rust', 'scab']
y =  ['healthy', 'multiple diseases', 'Rust', 'scab']

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

# set up figure 
fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

# add title
fig.update_layout(title_text='<i><b>Confusion matrix</b></i>',
                  #xaxis = dict(title='x'),
                  #yaxis = dict(title='x')
                 )

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.35,
                        y=0.5,
                        showarrow=False,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))

# adjust margins to make room for yaxis title
fig.update_layout(margin=dict(t=50, l=200))

# add colorbar
fig['data'][0]['showscale'] = True
fig.show()

# %%
a = "Hola Sofi gracias lo voy a tener en cuenta, cualquier cosa me comunico con esa gente gracias"

# %%
b = tokenize(a)

# %%
df.tipo.value_counts()
# Out:
# DISCONFORMIDAD_CLIENTE    12682
# ERROR_DESPEGAR             4412
# ERROR_PROVEEDOR             912
# DECISION_DE_NEGOCIO         447
# SIN_IDENTIFICAR             354
# FRAUDE                       90
# Name: tipo, dtype: int64

# %%
df1 = df.drop(columns= 'id')
df1['fecha'] = df1['fecha_notificacion'].astype('datetime64[ns]')
df1.index = df1.fecha
df1 = df1.sort_index()

df1['fecha']import plotly.figure_factory as ff

z = [[0.1, 0.3, 0.5, 0.2],
     [1.0, 0.8, 0.6, 0.1],
     [0.1, 0.3, 0.6, 0.9],
     [0.6, 0.4, 0.2, 0.2]]

x = ['healthy', 'multiple diseases', 'Rust', 'scab']
y =  ['healthy', 'multiple diseases', 'Rust', 'scab']

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

# set up figure 
fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

# add title
fig.update_layout(title_text='<i><b>Confusion matrix</b></i>',
                  #xaxis = dict(title='x'),
                  #yaxis = dict(title='x')
                 )

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.35,
                        y=0.5,
                        showarrow=False,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))

# adjust margins to make room for yaxis title
fig.update_layout(margin=dict(t=50, l=200))

# add colorbar
fig['data'][0]['showscale'] = True
fig.show() = df1['fecha'].astype('datetime64[ns]')

# %%
df2 = df1['2019':]

# %%
df1['Year'] = df1['fecha'].dt.year 
df1['Month'] = df1['fecha'].dt.month
df1['fecha'] = pd.to_datetime(list(df1['fecha']))

# %%
#Grafico distribucion de reclamos en el tiempo
fig_since_2020 = px.histogram(df2, x='fecha', template="plotly_dark",  title="Reclamos por mes", labels={'fecha':"año"}, nbins=12)
fig_since_2020.show()

# %%
fig_since_2020.write_html('fig_since_2019.html')

# %%
df2 = df2[['fecha','tipo','sub_tipo','hechos_segun_pasajero']]

# %%
import plotly.figure_factory as ff

z = [[0.1, 0.3, 0.5, 0.2],
     [1.0, 0.8, 0.6, 0.1],
     [0.1, 0.3, 0.6, 0.9],
     [0.6, 0.4, 0.2, 0.2]]

x = ['healthy', 'multiple diseases', 'Rust', 'scab']
y =  ['healthy', 'multiple diseases', 'Rust', 'scab']

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

# set up figure 
fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

# add title
fig.update_layout(title_text='<i><b>Confusion matrix</b></i>',
                  #xaxis = dict(title='x'),
                  #yaxis = dict(title='x')
                 )

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.35,
                        y=0.5,
                        showarrow=False,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))

# adjust margins to make room for yaxis title
fig.update_layout(margin=dict(t=50, l=200))

# add colorbar
fig['data'][0]['showscale'] = True
fig.show()
# Out:
# (15805, 4)

# %%
df2.fecha.value_counts()
# Out:
# 2020-04-14    170
# 2020-06-04    144
# 2020-04-28    142
# 2020-04-13    139
# 2020-04-22    138
#              ...
# 2020-03-21      1
# 2020-08-02      1
# 2020-12-30      1
# 2020-07-03      1
# 2020-02-29      1
# Name: fecha, Length: 349, dtype: int64

# %%
import plotly.figure_factory as ff

z = [[0.1, 0.3, 0.5, 0.2, 0.2, 0.2],
     [1.0, 0.8, 0.6, 0.1, 0.2, 0.2],
     [0.1, 0.3, 0.6, 0.9, 0.2, 0.2],
     [0.1, 0.3, 0.6, 0.9, 0.2, 0.2],
     [0.1, 0.3, 0.6, 0.9, 0.2, 0.2],
     [0.6, 0.4, 0.2, 0.2, 0.2, 0.2]]

x = [0,1,2,3,4,5]
y =  ['DECISION_DE_NEOGOCIO','DISCONFORMIDAD_CLIENTE','ERROR_EMPRESA','ERROR_PROVEEDOR','FRAUDE','SIN_IDENTIFICAR']

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

colorscale = [[0, 'navy'], [1, 'plum']]
# set up figure 

fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text,colorscale=colorscale)

# add title
fig.update_layout(
                  #xaxis = dict(title='x'),
                  #yaxis = dict(title='x')
                 )

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.20,
                        y=0.5,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))



# add colorbar
fig['data'][0]['showscale'] = True
fig.show()

# %%
px.line(df2, y="tipo", template="plotly_dark",  title="Reclamos por Tipo - desde 2020", labels={'index':"año"})
